# %% [markdown]
# # Diabetes Prediction project

# %% [markdown]
# ## Initial raw data examination

# %% [markdown]
# In this notebook, we're going to load the whole dataset and get familiar with it. This is more like a sanity check,
# to get an idea about features, dataset shape, missing data, class balance, etc. Exploratory Data Analysis (EDA) will
# be done in a separate notebook.

# %% [markdown]
# ## Environment setup

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data examination

# %%
# Path of raw data in our project structure
raw_path = "../src/diabetes_prediction/data/raw/diabetes_prediction.csv"
target = "diabetes"

df = pd.read_csv(raw_path)
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
print(f"Raw dataset shape : {df.shape}")
# Out:
# Raw dataset shape : (100000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3854)

# %%
df[target].value_counts(normalize=True)
# Out:
# diabetes
# 0    0.915
# 1    0.085
# Name: proportion, dtype: float64

# %% [markdown]
# ## Summary

# %% [markdown]
# Key characteristics of this dataset can be summarized as follows :
# - Dataset has mixed feature types (some feature engineering is required in data pipeline).
# - Dataset has class imbalance, with only a small portion of instances in positive class (~9%).
# - Dataset has no missing values, although later EDA may reveal invalid data in categorical features.
# - Dataset has some duplicate data (~4%). These instances must be dropped before splitting the dataset.
